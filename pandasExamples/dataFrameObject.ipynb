# %%
import pandas as pd

# %%
d = pd.read_csv('weather.csv')

# %%
d.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
myDict = {
    'dates': ['02-01-18', '03-01-18', '04-01-18', '05-01-18', '06-01-18'],
    'day': ['sunny', 'rainy', 'hot', 'sunny', 'hot'],
    'wind-speed': [12, 34, 45, 56, 67],
    'temp': [45, 46, 47, 48, 49]
}
df = pd.DataFrame(myDict)
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-18  sunny          12    45
# 1  03-01-18  rainy          34    46
# 2  04-01-18    hot          45    47
# 3  05-01-18  sunny          56    48
# 4  06-01-18    hot          67    49

# %%
df['day']
# Out:
# 0    sunny
# 1    rainy
# 2      hot
# 3    sunny
# 4      hot
# Name: day, dtype: object

# %%
df['temp']
# Out:
# 0    45
# 1    46
# 2    47
# 3    48
# 4    49
# Name: temp, dtype: int64

# %%
df[['day', 'temp', 'wind-speed']]
# Out:
#      day  temp  wind-speed
# 0  sunny    45          12
# 1  rainy    46          34
# 2    hot    47          45
# 3  sunny    48          56
# 4    hot    49          67

# %%
df.shape
# Out:
# (5, 4)

# %%
d.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     31669.000000              31669.000000  31669.000000
# mean         11.828309                 10.697191      0.717960
# std           9.702414                 10.822627      0.192991
# min         -16.666667                -24.233333      0.000000
# 25%           4.383333                  1.983333      0.590000
# 50%          11.577778                 11.577778      0.770000
# 75%          18.888889                 18.888889      0.870000
# max          39.905556                 38.377778      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       31669.000000            31669.000000     31669.000000     31669.0
# mean           10.861736              191.138527        10.101487         0.0
# std             6.964968              106.222524         3.756646         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
d1 = d[d['Temperature (C)'] > 9]
d1
# Out:
#                       Formatted Date                   Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200             Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200             Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200             Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200             Partly Cloudy        rain
# 8      2006-04-01 08:00:00.000 +0200             Partly Cloudy        rain
# 9      2006-04-01 09:00:00.000 +0200             Partly Cloudy        rain
# 10     2006-04-01 10:00:00.000 +0200             Partly Cloudy        rain
# 11     2006-04-01 11:00:00.000 +0200             Partly Cloudy        rain
# 12     2006-04-01 12:00:00.000 +0200             Partly Cloudy        rain
# 13     2006-04-01 13:00:00.000 +0200             Partly Cloudy        rain
# 14     2006-04-01 14:00:00.000 +0200             Partly Cloudy        rain
# ...

# %%
d1.shape
# Out:
# (18308, 12)

# %%
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-18  sunny          12    45
# 1  03-01-18  rainy          34    46
# 2  04-01-18    hot          45    47
# 3  05-01-18  sunny          56    48
# 4  06-01-18    hot          67    49

# %%
df.set_index('dates', inplace = True)

# %%
df
# Out:
#             day  wind-speed  temp
# dates
# 02-01-18  sunny          12    45
# 03-01-18  rainy          34    46
# 04-01-18    hot          45    47
# 05-01-18  sunny          56    48
# 06-01-18    hot          67    49

# %%
df.loc['04-01-18']
# Out:
# day           hot
# wind-speed     45
# temp           47
# Name: 04-01-18, dtype: object

# %%
df.iloc[4]
# Out:
# day           hot
# wind-speed     67
# temp           49
# Name: 06-01-18, dtype: object

# %%
df.iloc[0:3]
# Out:
#             day  wind-speed  temp
# dates
# 02-01-18  sunny          12    45
# 03-01-18  rainy          34    46
# 04-01-18    hot          45    47

# %%
df.reset_index()
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-18  sunny          12    45
# 1  03-01-18  rainy          34    46
# 2  04-01-18    hot          45    47
# 3  05-01-18  sunny          56    48
# 4  06-01-18    hot          67    49
